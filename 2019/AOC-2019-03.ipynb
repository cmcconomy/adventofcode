# %%
import pandas as pd
import numpy as np
from enum import Enum

from aocutils.get_aoc_inputs import get_aoc_inputs

# %%
if 'inputs' not in locals():
    inputs = get_aoc_inputs(3)
    inputs_wire1 = inputs[0].split(',')
    inputs_wire2 = inputs[1].split(',')

class LineType(Enum):
    VERTICAL=1
    HORIZONTAL=2
    
class Segment:
    def __init__(self, x, y, instruction):
        direction = instruction[0]
        amount = int(instruction[1:])
        if( direction == "U" ):
            self.direction = LineType.VERTICAL
            self.endx = x
            self.endy = y + amount
            self.x1 = x
            self.x2 = x
            self.y1 = y
            self.y2 = self.endy
        elif( direction == "D" ):
            self.direction = LineType.VERTICAL
            self.endx = x
            self.endy = y - amount
            self.x1 = x
            self.x2 = x
            self.y1 = self.endy
            self.y2 = y 
        elif( direction == "L" ):
            self.direction = LineType.HORIZONTAL
            self.endx = x - amount
            self.endy = y
            self.x1 = self.endx
            self.x2 = x
            self.y1 = y 
            self.y2 = y 
        elif( direction == "R" ):
            self.direction = LineType.HORIZONTAL
            self.endx = x + amount
            self.endy = y
            self.x1 = x 
            self.x2 = self.endx
            self.y1 = y 
            self.y2 = y 
    
def get_segments(wiring_diagram):
    x=0
    y=0
    segments = []
    for instruction in wiring_diagram:
        segment = Segment(x,y,instruction)
        segments.append(segment)
        x = segment.endx
        y = segment.endy
        
    print( segments )
    
test_inputs_1 = [
    {"test_in":["R8,U5,L5,D3","U7,R6,D4,L4"], "test_out":6},
]
    
def test_part1():
    for test_input in test_inputs_1:
        wires1 = test_input["test_in"][0].split(",")
        wires2 = test_input["test_in"][1].split(",")
        get_segments(wires1)

#         ti = test_input["test_in"]
#         assert 1==1, "Good"
        
def day1():
    return
        


test_part1()
# day1()

# ------------------------------------------------------------------------------------------

test_inputs_2 = [
    {"test_in":[], "test_out":[]},
]
    
def test_part2():
    for test_input in test_inputs_2:
        ti = test_input["test_in"]
        assert 1==1, "Good"
        
def day1():
    return
            
# test_part2()
# day2()
# Out:
# [<__main__.Segment object at 0x10ff40430>, <__main__.Segment object at 0x10ff405e0>, <__main__.Segment object at 0x10ff40ee0>, <__main__.Segment object at 0x10ff408e0>]
